# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df_disney = pd.read_csv('disney_movies_total_gross.csv')

# %%
df_disney
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# ...

# %%
def answer_one():
    return df_disney.sort_values(by='inflation_adjusted_gross').reset_index()

# %%
answer_one()
# Out:
#      index                             movie_title release_date      genre  \
# 0       27                                     Amy   1981-03-20      Drama
# 1       20  The Many Adventures of Winnie the Pooh   1977-03-11        NaN
# 2      355                     Frank McKlusky C.I.   2002-01-01        NaN
# 3       29                               Condorman   1981-08-07     Action
# 4      511                                Zokkomon   2011-04-22  Adventure
# ..     ...                                     ...          ...        ...
# 574      6                      Lady and the Tramp   1955-06-22      Drama
# 575      8                          101 Dalmatians   1961-01-25     Comedy
# 576      2                                Fantasia   1940-11-13    Musical
# 577      1                               Pinocchio   1940-02-09  Adventure
# 578      0         Snow White and the Seven Dwarfs   1937-12-21    Musical
#
#     mpaa_rating  total_gross  inflation_adjusted_gross
# ...

# %%
df_top = df_disney.max(0)

# %%
df = df_disney.groupby(['movie_title']).mean()

# %%
df
# Out:
#                               total_gross  inflation_adjusted_gross
# movie_title
# 101 Dalmatians                144594647.0               810799941.5
# 102 Dalmatians                 66941559.0               104055039.0
# 1492: Conquest of Paradise      7099531.0                14421454.0
# 20,000 Leagues Under the Sea   28200000.0               528279994.0
# 25th Hour                      13084595.0                18325463.0
# ...                                   ...                       ...
# You Again                      25702053.0                27461121.0
# Young Black Stallion            6751389.0                 9254344.0
# Zokkomon                           2815.0                    2984.0
# Zootopia                      341268248.0               341268248.0
# crazy/beautiful                16929123.0                25214223.0
#
# [573 rows x 2 columns]

# %%
df = df_disney.groupby(['genre']).mean()

# %%
df
# Out:
#                       total_gross  inflation_adjusted_gross
# genre
# Action               1.046141e+08              1.374734e+08
# Adventure            1.270471e+08              1.903974e+08
# Black Comedy         3.251440e+07              5.224349e+07
# Comedy               4.461329e+07              8.466773e+07
# Concert/Performance  5.172823e+07              5.741084e+07
# Documentary          1.129285e+07              1.271803e+07
# Drama                3.602608e+07              7.189302e+07
# Horror               1.451148e+07              2.341385e+07
# Musical              7.233026e+07              6.035979e+08
# Romantic Comedy      5.009595e+07              7.777708e+07
# Thriller/Suspense    5.861694e+07              8.965379e+07
# Western              5.128735e+07              7.381571e+07

# %%
df = df_disney.groupby(['release_date']).mean()

# %%
df
# Out:
#               total_gross  inflation_adjusted_gross
# release_date
# 1937-12-21    184925485.0              5.228953e+09
# 1940-02-09     84300000.0              2.188229e+09
# 1940-11-13     83320000.0              2.187091e+09
# 1946-11-12     65000000.0              1.078511e+09
# 1950-02-15     85000000.0              9.206087e+08
# ...                   ...                       ...
# 2016-09-02     12545979.0              1.254598e+07
# 2016-09-23      8874389.0              8.874389e+06
# 2016-11-04    232532923.0              2.325329e+08
# 2016-11-23    246082029.0              2.460820e+08
# 2016-12-16    529483936.0              5.294839e+08
#
# [553 rows x 2 columns]

# %%
df_disney.groupby(['genre']).mean().plot(figsize=(16,7))
# Out:
# <AxesSubplot:xlabel='genre'>

# %%
df_disney.groupby(['release_date']).idxmax().plot(figsize=(16,7))
# Out:
# <AxesSubplot:xlabel='release_date'>

# %%
df_disney.groupby(['genre']).count().plot(kind= 'bar',figsize=(14,7))
# Out:
# <AxesSubplot:xlabel='genre'>

# %%
df_disney.groupby(['genre']).count().plot(y= "total_gross",kind= 'bar',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='genre'>

# %%
df_disney['genre'].hist()
# Out:
# <AxesSubplot:>
