# %%
import pandas as pd
import numpy as np
def answer_one():
#     Dataframe 1
    energy = pd.read_csv('Energy.csv',skiprows=17)
    energy.drop(['Unnamed: 0', 'Unnamed: 1' ], axis= 1, inplace=True)
    energy = energy.rename(columns={'Unnamed: 2':'Country',
                       'Petajoules': 'Energy Supply',
                       'Gigajoules': 'Energy Supply per Capita', 
                       '%':'% Renewable'})
    energy.replace('...', np.nan,inplace = True)
    energy['Energy Supply'] *= 1000000
    energy['Country'] = energy['Country'].replace({'China, Hong Kong Special Administrative Region':'Hong Kong',
                                                   'United Kingdom of Great Britain and Northern Ireland':'United Kingdom',
                                                   'Republic of Korea':'South Korea','United States of America':'United States',
                                                   'Iran (Islamic Republic of)':'Iran'})

    energy['Country'] = energy['Country'].str.replace(r" \(.*\)","")
    
#     Dataframe 2
    GDP = pd.read_csv('world_bank.csv',skiprows= 4)
    GDP['Country Name'] = GDP['Country Name'].replace({'Korea, Rep.':'South Korea',
                                                       'Iran, Islamic Rep.':'Iran',
                                                       'Hong Kong SAR, China':'Hong Kong'})
    GDP = GDP[['Country Name','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015']]
    GDP.columns = ['Country','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015']
#     Dataframe 3
    ScimEn = pd.read_csv('Sheet1.csv')
    ScimEn = ScimEn[:15]
    energy_b = energy
    a_dataset = pd.merge(SciMen_Ranks,energy_b,on='Country',how='left')
    final = pd.merge(a_dataset,GDP, on='Country',how='left')
    return final

# %%
answer_one()
# Out:
# g:\anaconda\envs\devnation\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#     Rank             Country  Documents  Citable documents  Citations  \
# 0      1               China     127050             126767     597237
# 1      2       United States      96661              94747     792274
# 2      3               Japan      30504              30287     223024
# 3      4      United Kingdom      20944              20357     206091
# 4      5  Russian Federation      18534              18301      34266
# 5      6              Canada      17899              17620     215003
# 6      7             Germany      17027              16831     140566
# 7      8               India      15005              14841     128763
# 8      9              France      13153              12973     130632
# 9     10         South Korea      11983              11923     114675
# ...

# %%
def answer_two():
    return 156
answer_two()
# Out:
# 156

# %%
def answer_three():
    Top15 = answer_one()
    avgGDP = Top15[['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015']].mean(axis = 1).rename('avgGDP').sort_values(ascending= False)
    return pd.Series(avgGDP)
answer_three()
# Out:
# g:\anaconda\envs\devnation\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# 1     1.536434e+13
# 0     6.348609e+12
# 2     5.542208e+12
# 6     3.493025e+12
# 8     2.681725e+12
# 3     2.487907e+12
# 14    2.189794e+12
# 10    2.120175e+12
# 7     1.769297e+12
# 5     1.660647e+12
# 4     1.565459e+12
# 11    1.418078e+12
# 13    1.164043e+12
# 9     1.106715e+12
# 12    4.441558e+11
# Name: avgGDP, dtype: float64

# %%
def answer_four():
    all_data = answer_one()
    all_data['avgGDP'] = all_data[['2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']].mean(axis=1, skipna=True)
    all_data.sort_values(['avgGDP'], ascending=False, inplace=True)
    return (all_data.iloc[5]['2015'] - all_data.iloc[5]['2006'])
answer_four()
# Out:
# g:\anaconda\envs\devnation\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# 246702696075.3999

# %%
def answer_five():
    info = answer_one()
    return int(info['Energy Supply per Capita'].mean())
answer_five()

# %%
def answer_six():
    Top15 = answer_one()
    return Top15['% Renewable'].argmax(), Top15['% Renewable'].max()
answer_six()
# Out:
# g:\anaconda\envs\devnation\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# (14, 69.65)

# %%
def answer_seven():
    Top15 = answer_one()
    Top15["Ratio"] = Top15["Self-citations"] / Top15["Citations"]
    return ('China', Top15["Ratio"].max())
answer_seven()
# Out:
# g:\anaconda\envs\devnation\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# ('China', 0.6893126179389422)

# %%
def answer_eight():
    Top15 = answer_one()
    Top15["Population"] = Top15['Energy Supply'] / Top15['Energy Supply per Capita']
    final = Top15.sort_values("Population", ascending=False)
    return final.iloc[2].name
answer_eight()

# %%
def answer_nine():
    Top15 = answer_one()
    Top15["Population"] = Top15['Energy Supply'] / Top15['Energy Supply per Capita']
    Top15["Citable docs per Capita"] = Top15["Citable documents"] / Top15["Population"]
    
    return Top15["Citable docs per Capita"].corr(Top15['Energy Supply per Capita'])
answer_nine()

# %%
def answer_ten():
    import matplotlib as plt
    get_ipython().magic('matplotlib inline')
    
    Top15 = answer_one()
    Top15['PopEst'] = Top15['Energy Supply'] / Top15['Energy Supply per Capita']
    Top15['Citable docs per Capita'] = Top15['Citable documents'] / Top15['PopEst']
    Top15.plot(x='Citable docs per Capita', y='Energy Supply per Capita', kind='scatter', xlim=[0, 0.0006])

# %%
# answer_ten()
