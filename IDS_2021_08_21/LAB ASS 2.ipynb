# %%
import pandas as pd
import numpy as np

# read file
# data cleaning
#
def answer_one():
    energy=pd.read_excel('Energy+Indicators.xls',skiprows=17, usecols="C,D,E,F")
    energy = energy.rename(columns={'Unnamed: 2': 'country', 'Petajoules': 'Energy Supply','Gigajoules':'Energy Supply per Capita', '%':' % Renewable'})
    energy=energy.rename(index={"Republic of Korea": "South Korea", "United States of America": "United States", "United Kingdom of Great Britain and Northern Ireland": "United Kingdom", "China, Hong Kong Special Administrative Region": "Hong Kong",'Plurinational State of' : 'Bolivia','Switzerland17' :'Switzerland'})
    energy['Energy Supply']=energy['Energy Supply']*1000000
    energy.set_index('country', inplace = True)
    energy.head()

    # print(**********************************************************)

    GDP = pd.read_csv("world_bank.csv",skiprows = 4)
    GDP.rename(columns = {"Country Name": "country"}, inplace = True)

    GDP['country'] = GDP['country'].replace({'Korea, Rep.':'South Korea','Iran, Islamic Rep.':'Iran','Hong Kong SAR, China':'Hong Kong'})

    GDP.set_index('country', inplace = True)
    GDP=GDP.rename(index={"Korea, Rep.": "South Korea", "Iran, Islamic Rep.": "Iran", "Hong Kong SAR, China": "Hong Kong"})
    GDP = GDP[GDP.columns[49:] ]

    GDP.head()


    # print(**********************************************************)


    ScimEn = pd.read_excel('scimagojr-3.xlsx')
    ScimEn.rename(columns = {"Country": "country"}, inplace = True)
    ScimEn.set_index('country', inplace = True)
    ScimEn =ScimEn.head(15)
    ScimEn


    # **************************************************

    result = ScimEn.join([energy, GDP]).sort_values(by= 'Rank', ascending = True)
    return result.head(15)

    # **************************************************


    # result = energy.join([GDP, ScimEn])
    # result
    # result.head(15)
    # **************************************************


    # result = ScimEn.join([energy, GDP])
    # result
    # result.head(15)

    # join by inner method 
#     df_inner = pd.merge(ScimEn,energy, on='country', how='inner')

#     df_inner1 = pd.merge(df_inner, GDP, on='country', how='inner')

#     return df_inner1

# %%
answer_one()
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
def answer_two():
    total = energy + GDP + ScimEn
    return len(total) - len(result)
answer_two()
# Out:
# 349

# %%
def answer_three():
    gdp =answer_one()
    avgGDP = gdp[['2006', '2007', '2008','2009', '2010', '2011', '2012', '2013', '2014', '2015']].mean(skipna = True).sort_values(ascending = False)
    return avgGDP
answer_three()
# Out:
# 2015    3.875826e+12
# 2014    3.562304e+12
# 2013    3.470126e+12
# 2012    3.391038e+12
# 2011    3.313404e+12
# 2010    3.219173e+12
# 2008    3.141171e+12
# 2007    3.095871e+12
# 2009    3.085834e+12
# 2006    2.978152e+12
# dtype: float64

# %% [markdown]
# Question 4
# By how much had the GDP changed over the 10 year span for the country with the 6th largest average
# GDP?
# This function should return a single number.

# %%
def answer_four():
    gdp =answer_one()
    avgGDP = gdp[['2006', '2007', '2008','2009', '2010', '2011', '2012', '2013', '2014', '2015']].mean(skipna = True).sort_index(ascending = True)
    gdp['avgGDP'] =avgGDP
#     x =avgGDP[6]
#     x = x.pct_change()
    gdp.sort_values(by = 'avgGDP',ascending = False,inplace = True)
    return avgGDP[6]
    
# 
print(answer_four())
# Out:
# 3391038344902.4707

# %%
def answer_five():
    gdp =answer_one()
    mean_energy = gdp['Energy Supply per Capita'].mean()
    return mean_energy

answer_five()
# Out:
# 152.0

# %%
def answer_six():
    gdp =answer_one()
    return gdp[' % Renewable'].idxmax(),gdp[' % Renewable'].max()

answer_six()
# Out:
# ('Brazil', 69.64803)

# %% [markdown]
# Question 7
# Create a new column that is the ratio of Self-Citations to Total Citations. What is the maximum value for
# this new column, and what country has the highest ratio?
# This function should return a tuple with the name of the country and the ratio

# %%
def answer_seven():
    gdp =answer_one()
    total = gdp['Self-citations'].sum(axis=0,skipna=False)
    gdp['ratio'] = (['Self-citations']/total).max().sort_values()
    return gdp['ratio']

answer_seven()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-a24fb6403507> in <module>
#       5     return gdp['ratio']
#       6
# ----> 7 answer_seven()
#       8
#
# <ipython-input-66-a24fb6403507> in answer_seven()
#       2     gdp =answer_one()
#       3     total = gdp['Self-citations'].sum(axis=0,skipna=False)
# ----> 4     gdp['ratio'] = (['Self-citations']/total).max().sort_values()
#       5     return gdp['ratio']
#       6
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
Create a column that estimates the population using Energy Supply and Energy Supply per capita. What is
the third most populous country according to this estimate?
This function should return a single string value.

# %%
def answer_eight():
    gdp =answer_one()

    gdp['population'] = gdp['Energy Supply']/gdp['Energy Supply per Capita']
    gdp.sort_values(by='population',ascending = False,inplace= True)

    return  gdp['population'][2]
answer_eight()
# Out:
# 143500000.0

# %%
# Create a column that estimates the number of citable documents per person. 
# What is the correlation between the number of citable documents per capita and the energy supply per capita? Use the `.corr()` method, (Pearson's correlation).
# 
# 
def answer_nine():
    df = answer_one()
    df['population']=df['Energy Supply']/df['Energy Supply per Capita']
    df['citable documents per person']=df['Citable documents']/df['population']
    df['citable documents per person']=(df['citable documents per person'])
#     relation = df['citable documents per person'].corr(df['Energy Supply per Capita'])
    return df['citable documents per person']
answer_nine()
# Out:
# country
# China                      NaN
# United States              NaN
# Japan                      NaN
# United Kingdom             NaN
# Russian Federation    0.000128
# Canada                  0.0005
# Germany               0.000209
# India                 0.000012
# France                     NaN
# South Korea                NaN
# Italy                      NaN
# Spain                      NaN
# Iran                       NaN
# Australia                  NaN
# Brazil                0.000042
# Name: citable documents per person, dtype: object

# %%
def answer_ten():
    df = answer_one()
    renewable_mean = df[' % Renewable'].median()       
    def function(x):
        if x>=renewable_mean:
            return 1
        else:
            return 0
    df['HighRenew']=df[' % Renewable'].map(lambda x:1 if x>=renewable_mean else 0)
    df.sort_values(by='Rank',ascending = True)
    return(df['HighRenew'])
print(answer_ten())
# Out:
# country
# China                 0
# United States         0
# Japan                 0
# United Kingdom        0
# Russian Federation    0
# Canada                1
# Germany               1
# India                 0
# France                0
# South Korea           0
# Italy                 0
# Spain                 0
# Iran                  0
# Australia             0
# Brazil                1
# Name: HighRenew, dtype: int64

# %%
def answer_eleven():
    df = answer_one()
    df['population']=df['Energy Supply']/df['Energy Supply per Capita']
    df['population'] = np.float64(df['population'])
    ContinentDict = {'China':'Asia', 'United States':'North America', 'Japan':'Asia', 'United Kingdom':'Europe', 'Russian Federation':'Europe', 'Canada':'North America','Germany':'Europe','India':'Asia','France':'Europe','South Korea':'Asia', 'Italy':'Europe', 'Spain':'Europe','Iran':'Asia','Australia':'Australia','Brazil':'South America'}
    
    df.rename(index=ContinentDict,inplace=True)
    df.reset_index(inplace = True)
    functions = ['size', 'sum', 'mean', 'std']
    result = df[['country','population']].groupby('country').agg(functions)
    return(result)
answer_eleven()
# Out:
#               population
#                     size           sum          mean           std
# country
# Asia                   5  1.276731e+09  1.276731e+09           NaN
# Australia              1  0.000000e+00           NaN           NaN
# Europe                 6  2.238697e+08  1.119348e+08  4.463987e+07
# North America          2  3.523986e+07  3.523986e+07           NaN
# South America          1  2.059153e+08  2.059153e+08           NaN

# %%
Use the following dictionary to group the Countries by Continent, then create a dateframe that displays
the sample size (the number of countries in each continent bin), and the sum, mean, and std deviation for
the estimated population of each country.

# %% [markdown]
# Cut % Renewable into 5 bins. Group Top15 by the Continent, as well as these new % Renewable bins.
# How many countries are in each of these groups?
# This function should return a Series with a MultiIndex of Continent, then the bins for % Renewable. Do not
# include groups with no countries.

# %%
def answer_twelve():
    df = answer_one()
    df1 = answer_eleven()
#     x = df1.head(5)
#     df['Country']= x.index
    df['bin'] = pd.qcut(df[' % Renewable'], q=5)     # Cut % Renewable into 5 bins

    grouped = df.groupby(['bin'])


    return grouped

answer_twelve()

# %% [markdown]
# # Question 13
# Convert the Population Estimate series to a string with thousands separator (using commas). Do not
# round the results.
# e.g. 317615384.61538464 -> 317,615,384.61538464
# This function should return a Series PopEst whose index is the country name and whose values are the
# population estimate string.

# %%
def answer_thirteen():
    df['population']=df['Energy Supply']/df['Energy Supply per Capita']
    str(pd.Series(df['population']))
    return df['population'] 

answer_thirteen()
# Out:
# country
# Brazil                 205915254.237288
# Canada                  35239864.864865
# Germany                 80369696.969697
# India                 1276730769.230769
# Russian Federation          143500000.0
# Name: population, dtype: object
