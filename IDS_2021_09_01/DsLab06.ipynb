# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def answer_one():
    df = pd.read_csv('disney_movies_total_gross.csv')
    return df

answer_one()
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# ...

# %%
def answer_two():
    Top10 = df.sort_values(by = 'inflation_adjusted_gross', ascending = False)
    return Top10.head(10)
answer_two()
# Out:
#                               movie_title release_date      genre mpaa_rating  \
# 0         Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                               Pinocchio   1940-02-09  Adventure           G
# 2                                Fantasia   1940-11-13    Musical           G
# 8                          101 Dalmatians   1961-01-25     Comedy           G
# 6                      Lady and the Tramp   1955-06-22      Drama           G
# 3                       Song of the South   1946-11-12  Adventure           G
# 564  Star Wars Ep. VII: The Force Awakens   2015-12-18  Adventure       PG-13
# 4                              Cinderella   1950-02-15      Drama           G
# 13                        The Jungle Book   1967-10-18    Musical   Not Rated
# 179                         The Lion King   1994-06-15  Adventure           G
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# ...

# %%
def answer_three():
    genre = df.groupby(['genre']).mean()
    pop_genre = genre.reset_index()
    pop_genre['inflation_adjusted_gross'] = pop_genre['inflation_adjusted_gross'].astype(int)
    pop_genre = pop_genre.sort_values(by = 'inflation_adjusted_gross', ascending = False)
    return pop_genre.head(10)
answer_three()
# Out:
#                   genre   total_gross  inflation_adjusted_gross
# 8               Musical  7.233026e+07                 603597861
# 1             Adventure  1.270471e+08                 190397412
# 0                Action  1.046141e+08                 137473419
# 10    Thriller/Suspense  5.861694e+07                  89653789
# 3                Comedy  4.461329e+07                  84667730
# 9       Romantic Comedy  5.009595e+07                  77777084
# 11              Western  5.128735e+07                  73815706
# 6                 Drama  3.602608e+07                  71893021
# 4   Concert/Performance  5.172823e+07                  57410839
# 2          Black Comedy  3.251440e+07                  52243491

# %%
def answer_four():
    Top10 = answer_two()
    plt.figure(figsize=(10,10))
    sns.barplot(x=pop_genre.genre, y=pop_genre.inflation_adjusted_gross)
    plt.xlabel("Genre")
    plt.ylabel("Gross Income (billions)")
    plt.xticks(rotation = 90)
    plt.tight_layout()
    return plt.show()
answer_four()

# %%
# Graph for Movie Profits over time

df['year'] = pd.DatetimeIndex(df['release_date']).year
plt.figure(figsize=(10,10))
sns.lineplot(x=genre2.year,y=genre2.inflation_adjusted_gross)
plt.xlabel("Year", size = 10)
plt.ylabel("Gross Income (billions)", size = 10)
plt.tight_layout()
plt.show()

# %%
# Graph for Genre Profits over time


plt.figure(figsize=(10,10))
sns.lineplot(x=genre2.year,y=genre2.inflation_adjusted_gross, hue=genre2.genre)
plt.xlabel("Year", size = 10)
plt.ylabel("Gross Income (billions)", size = 10)
plt.tight_layout()
plt.show()

# %%
# Graph for Top 10 movies income

Top10 = answer_two()
plt.figure(figsize=(10,10))
sns.barplot(x=Top10.movie_title,y=Top10.inflation_adjusted_gross, palette="Paired")
plt.xlabel("Movie", size = 10)
plt.ylabel("Gross Income (billions)", size = 10)
plt.xticks(rotation = 90)
plt.tight_layout()
plt.show()
