# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt

# %%
df = pd.read_csv('disney_movies_total_gross.csv')

# %%
df.head()
# Out:
#                        movie_title release_date      genre mpaa_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 3                Song of the South   1946-11-12  Adventure           G
# 4                       Cinderella   1950-02-15      Drama           G
#
#    total_gross  inflation_adjusted_gross
# 0    184925485                5228953251
# 1     84300000                2188229052
# 2     83320000                2187090808
# 3     65000000                1078510579
# 4     85000000                 920608730

# %%
def answer_two():
    df1 = df.sort_values(by = 'inflation_adjusted_gross', ascending = False)
    return df1.head(10)
answer_two()
# Out:
#                               movie_title release_date      genre mpaa_rating  \
# 0         Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                               Pinocchio   1940-02-09  Adventure           G
# 2                                Fantasia   1940-11-13    Musical           G
# 8                          101 Dalmatians   1961-01-25     Comedy           G
# 6                      Lady and the Tramp   1955-06-22      Drama           G
# 3                       Song of the South   1946-11-12  Adventure           G
# 564  Star Wars Ep. VII: The Force Awakens   2015-12-18  Adventure       PG-13
# 4                              Cinderella   1950-02-15      Drama           G
# 13                        The Jungle Book   1967-10-18    Musical   Not Rated
# 179                         The Lion King   1994-06-15  Adventure           G
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# ...

# %%
def answer_three():
    pop_genre = df[['movie_title' ,'Year','genre']].groupby(by="genre").count().reset_index()
    final = pop_genre.sort_values(by = 'movie_title', ascending = False)
    
#     group_by_year = df[['inflation_adjusted_gross' ,'Year']].groupby(['Year']).count()

# group_by_year.sort_values(by = 'inflation_adjusted_gross', ascending = False)
    
    return final
answer_three()
# Out:
#                   genre  movie_title  Year
# 3                Comedy          182   182
# 1             Adventure          129   129
# 6                 Drama          114   114
# 0                Action           40    40
# 10    Thriller/Suspense           24    24
# 9       Romantic Comedy           23    23
# 5           Documentary           16    16
# 8               Musical           16    16
# 11              Western            7     7
# 7                Horror            6     6
# 2          Black Comedy            3     3
# 4   Concert/Performance            2     2

# %%
pop_genre = df.groupby(by="genre").count()
pop_genre.sort_values(by = 'movie_title', ascending = False)
 df1.plot(x='difference_pts', y='super_bowl', kind='hist',  figsize=(12,7))
# Out:
#                      movie_title  release_date  mpaa_rating  total_gross  \
# genre
# Comedy                       182           182          162          182
# Adventure                    129           129          119          129
# Drama                        114           114          103          114
# Action                        40            40           36           40
# Thriller/Suspense             24            24           23           24
# Romantic Comedy               23            23           22           23
# Documentary                   16            16           16           16
# Musical                       16            16           15           16
# Western                        7             7            7            7
# Horror                         6             6            5            6
# Black Comedy                   3             3            3            3
# Concert/Performance            2             2            2            2
#
# ...

# %%
df.dtypes
# Out:
# movie_title                 object
# release_date                object
# genre                       object
# mpaa_rating                 object
# total_gross                  int64
# inflation_adjusted_gross     int64
# Year                         int64
# dtype: object

# %%
df['Year'] =pd.to_datetime(df['release_date']).dt.year

# %%
df.dtypes
# Out:
# movie_title                 object
# release_date                object
# genre                       object
# mpaa_rating                 object
# total_gross                  int64
# inflation_adjusted_gross     int64
# Year                         int64
# dtype: object

# %%
df
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross  Year
# ...

# %%
group_by_year = df[['movie_title' ,'Year']].groupby(['Year']).count()

group_by_year.sort_values(by = 'movie_title', ascending = False)
# Out:
#       movie_title
# Year
# 2016           14
# 2015           11
# 2014           12
# 2013           11
# 2012           10
# 2011           14
# 2010           14
# 2009           16
# 2008           13
# 2007           14
# 2006           19
# 2005           17
# 2004           19
# 2003           19
# 2002           22
# 2001           14
# 2000           19
# 1999           21
# 1998           22
# 1997           23
# 1996           28
# 1995           32
# 1994           30
# 1993           27
# 1992           22
# 1991           16
# 1990           15
# 1989           11
# 1988           12
# 1987           10
# 1986            7
# 1985            6
# 1984            2
# 1983            4
# 1982            3
# 1981            4
# 1980            2
# 1979            1
# 1977            4
# 1975            1
# 1971            1
# 1970            2
# 1968            1
# 1967            1
# 1963            1
# 1962            1
# 1961            3
# 1959            1
# ...

# %%
def answer_four():
    return 

answer_four()

# %%
plot of

# %%
df1 = df.sort_values(by = 'inflation_adjusted_gross', ascending = False)
x= df1.head(10)
x
# Out:
#                               movie_title release_date      genre mpaa_rating  \
# 0         Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                               Pinocchio   1940-02-09  Adventure           G
# 2                                Fantasia   1940-11-13    Musical           G
# 8                          101 Dalmatians   1961-01-25     Comedy           G
# 6                      Lady and the Tramp   1955-06-22      Drama           G
# 3                       Song of the South   1946-11-12  Adventure           G
# 564  Star Wars Ep. VII: The Force Awakens   2015-12-18  Adventure       PG-13
# 4                              Cinderella   1950-02-15      Drama           G
# 13                        The Jungle Book   1967-10-18    Musical   Not Rated
# 179                         The Lion King   1994-06-15  Adventure           G
#
#      total_gross  inflation_adjusted_gross  Year
# 0      184925485                5228953251  1937
# ...

# %%
x.plot(x='Year', y='inflation_adjusted_gross', kind='bar',  figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
# dff = df[df['Year'] , df['inflation_adjusted_gross'], df['genre']]

df2 = df.drop(['movie_title','release_date','mpaa_rating', 'total_gross'], axis = 1)
df3 = df2.head(10)

# %%
df3.set_index('genre')
# Out:
#            inflation_adjusted_gross  Year
# genre
# Musical                  5228953251  1937
# Adventure                2188229052  1940
# Musical                  2187090808  1940
# Adventure                1078510579  1946
# Drama                     920608730  1950
# Adventure                 528279994  1954
# Drama                    1236035515  1955
# Drama                      21505832  1959
# Comedy                   1362870985  1961
# Comedy                    310094574  1961

# %%
df3.plot.bar(y='inflation_adjusted_gross', x = 'genre',figsize=(12, 7))
# Out:
# <AxesSubplot:xlabel='genre'>

# %%
df3.hist()
# Out:
# array([[<AxesSubplot:title={'center':'inflation_adjusted_gross'}>,
#         <AxesSubplot:title={'center':'Year'}>]], dtype=object)
